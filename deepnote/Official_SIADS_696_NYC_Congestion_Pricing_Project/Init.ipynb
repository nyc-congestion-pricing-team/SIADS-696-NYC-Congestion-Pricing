# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: folium in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (3.8.4)
# Collecting mapclassify (from -r ./requirements.txt (line 4))
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting altair==6.1.0 (from -r ./requirements.txt (line 5))
#   Downloading altair-6.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting umap-learn (from -r ./requirements.txt (line 6))
#   Downloading umap_learn-0.5.12-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from altair==6.1.0->-r ./requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /toolkit-cache/2.3.1/python3.11/kernel-libs/lib/python3.11/site-packages (from altair==6.1.0->-r ./requirements.txt (line 5)) (4.23.0)
# Requirement already satisfied: narwhals>=2.4.0 in /root/venv/lib/python3.11/site-packages (from altair==6.1.0->-r ./requirements.txt (line 5)) (2.22.1)
# Requirement already satisfied: packaging in /root/venv/lib/python3.11/site-packages (from altair==6.1.0->-r ./requirements.txt (line 5)) (26.2)
# Requirement already satisfied: typing-extensions>=4.12.0 in /root/venv/lib/python3.11/site-packages (from altair==6.1.0->-r ./requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: branca>=0.6.0 in /root/venv/lib/python3.11/site-packages (from folium->-r ./requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: numpy in /root/venv/lib/python3.11/site-packages (from folium->-r ./requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: requests in /root/venv/lib/python3.11/site-packages (from folium->-r ./requirements.txt (line 2)) (2.34.2)
# Requirement already satisfied: xyzservices in /root/venv/lib/python3.11/site-packages (from folium->-r ./requirements.txt (line 2)) (2026.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: networkx>=3.2 in /root/venv/lib/python3.11/site-packages (from mapclassify->-r ./requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: pandas>=2.1 in /root/venv/lib/python3.11/site-packages (from mapclassify->-r ./requirements.txt (line 4)) (2.1.4)
# Collecting scikit-learn>=1.4 (from mapclassify->-r ./requirements.txt (line 4))
#   Downloading scikit_learn-1.9.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.12 (from mapclassify->-r ./requirements.txt (line 4))
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.3 MB/s eta 0:00:00
# Collecting numba>=0.51.2 (from umap-learn->-r ./requirements.txt (line 6))
#   Downloading numba-0.65.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting pynndescent>=0.5 (from umap-learn->-r ./requirements.txt (line 6))
#   Downloading pynndescent-0.6.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.11/site-packages (from umap-learn->-r ./requirements.txt (line 6)) (4.68.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->altair==6.1.0->-r ./requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /root/venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.1.0->-r ./requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/2.3.1/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.1.0->-r ./requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/2.3.1/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.1.0->-r ./requirements.txt (line 5)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/2.3.1/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.1.0->-r ./requirements.txt (line 5)) (0.20.0)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba>=0.51.2->umap-learn->-r ./requirements.txt (line 6))
#   Downloading llvmlite-0.47.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas>=2.1->mapclassify->-r ./requirements.txt (line 4)) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas>=2.1->mapclassify->-r ./requirements.txt (line 4)) (2026.2)
# Requirement already satisfied: joblib>=0.11 in /root/venv/lib/python3.11/site-packages (from pynndescent>=0.5->umap-learn->-r ./requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->-r ./requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn>=1.4->mapclassify->-r ./requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests->folium->-r ./requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests->folium->-r ./requirements.txt (line 2)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /root/venv/lib/python3.11/site-packages (from requests->folium->-r ./requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /root/venv/lib/python3.11/site-packages (from requests->folium->-r ./requirements.txt (line 2)) (2026.5.20)
# Downloading altair-6.1.0-py3-none-any.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 58.2 MB/s eta 0:00:00
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 76.2 MB/s eta 0:00:00
# Downloading umap_learn-0.5.12-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 8.4 MB/s eta 0:00:00
# Downloading numba-0.65.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 91.8 MB/s eta 0:00:00
# Downloading pynndescent-0.6.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 8.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.9.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 130.4 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 111.1 MB/s eta 0:00:00
# Downloading llvmlite-0.47.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 112.0 MB/s eta 0:00:00
# Installing collected packages: scipy, llvmlite, scikit-learn, numba, pynndescent, mapclassify, umap-learn, altair
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# Successfully installed altair-6.1.0 llvmlite-0.47.0 mapclassify-2.10.0 numba-0.65.1 pynndescent-0.6.0 scikit-learn-1.9.0 scipy-1.17.1 umap-learn-0.5.12
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4a322346-8e1e-4650-8cef-fe9b767d96fb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
